# %%
import os
import colored

# %%
path = r"\\tambov1\vol16\URB_UVA\Обмен\OBMEN_AUD_DOC\Конкурс по разработке сервиса для проверки оформления офисных документов"
os.chdir(path=path)

# %%
#path = 'C:\\Users\\RVSLR\\123.docx'
#document = zipfile.ZipFile(path)
#xml_content = document.read('word/document.xml')
#document.close()
#tree = ET.parse(str(ET.XML(xml_content)))

# %%
pwd()
# Out:
# '\\\\tambov1\\vol16\\URB_UVA\\Обмен\\OBMEN_AUD_DOC\\Конкурс по разработке сервиса для проверки оформления офисных документов'

# %%
import docx
import re

# %%
doc = docx.Document('Распоряжение.docx')

# %%
for para in doc.paragraphs:
    for idx in para.runs:
        print(idx.text)
# Out:
# РАСПОРЯЖЕНИЕ
# УПРАВЛЕНИЕ ВНУТРЕННЕГО АУДИТА ЦЕНТРАЛЬНОГО АППАРАТА
#
# _____________
# 	№ _______________
# О
#
# проведении пилота
# трек
# а
#
# DE
#  СВА
# В целях развития в
# Службы внутреннего аудита (далее –
# СВА
# )
#  компетенций по направлению
# Data
#
# Engineer
#  (далее –
# DE
# )
# :
# Утвердить
# подходы по созданию и пилотированию Трека DE в СВА (Приложение
# 1);
# состав
#  Трека DE
# (
# Приложение
#  2
# )
# .
# Назначить
# :
#
# владельцем
# Т
# река
# DE
# О.В. Неелова -
# начальника отдел
# а
#  работы с централизованными данными
#
# (далее - ОРЦД)
# Управлени
# я
#  внутреннего аудита по Среднерусскому
# банку
# .
# куратором пилота Трека DE П.В. Щербакова – CDO СВА, руководителя направления Отдела планирования и развития
# (далее - ОПиР) Управления внутреннего аудита Центрального аппарата (далее – УВА ЦА)
# .
# Для реализации пилота Трека
# DE
#
# О.В. Неелов
# у
#  и П.В. Щербакову
# :
# в срок до
# 01
# .
# 04
# .
# 2021
#  обеспечить размещение
# трек
# а
# ...

# %%
for para in doc.paragraphs:
    #print(para.text)
    #print('===================================================================')
    for run in para.runs:
        print(colored.fg('black'),"[", run.text, "]", colored.fg('red'),run.bold, colored.fg('blue'),run.font.name, run.font.size )
        
    #print('----------------------------------------------------------------')
# Out:
#  [ РАСПОРЯЖЕНИЕ ]  True  Arial 203200
#  [ УПРАВЛЕНИЕ ВНУТРЕННЕГО АУДИТА ЦЕНТРАЛЬНОГО АППАРАТА ]  True  Arial 133350
#  [               ]  None  Arial 177800
#  [ _____________ ]  None  None 101600
#  [ 	№ _______________ ]  None  None 101600
#  [ О ]  True  Times New Roman 152400
#  [   ]  True  Times New Roman 152400
#  [ проведении пилота  ]  True  Times New Roman 152400
#  [ трек ]  True  Times New Roman 152400
#  [ а ]  True  Times New Roman 152400
#  [   ]  True  Times New Roman 152400
#  [ DE ]  True  Times New Roman 152400
#  [  СВА ]  True  Times New Roman 152400
#  [ В целях развития в  ]  None  Times New Roman 152400
#  [ Службы внутреннего аудита (далее –  ]  None  Times New Roman 152400
#  [ СВА ]  None  Times New Roman 152400
#  [ ) ]  None  Times New Roman 152400
#  [  компетенций по направлению  ]  None  Times New Roman 152400
#  [ Data ]  None  Times New Roman 152400
#  [   ]  None  Times New Roman 152400
#  [ Engineer ]  None  Times New Roman 152400
# ...
